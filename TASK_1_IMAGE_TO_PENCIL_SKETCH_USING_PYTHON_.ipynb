# %% [markdown]
# <a href="https://colab.research.google.com/github/yogesh82-dotcom/LGMVIP-DataScience/blob/main/TASK_1_IMAGE_TO_PENCIL_SKETCH_USING_PYTHON_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #TASK_1_IMAGE_TO_PENCIL_SKETCH_USING_PYTHON
# #NAME - YOGESH BALAJI G

# %%
from google.colab.patches import cv2_imshow

# %%
import cv2

# %%
img = cv2.imread("dhoni.png")

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=202x249 at 0x7F6C657AE290>

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
cv2_imshow(img_gray)
# Out:
# <PIL.Image.Image image mode=L size=202x249 at 0x7F6C64740CD0>

# %%
img_invert = cv2.bitwise_not(img_gray)

# %%
cv2_imshow(img_invert)
# Out:
# <PIL.Image.Image image mode=L size=202x249 at 0x7F6C64747F10>

# %%
img_smoothing = cv2.GaussianBlur(img, (21, 21), sigmaX=0, sigmaY=0)
img_smoothing_gray = cv2.GaussianBlur(img_gray, (21, 21), sigmaX=0, sigmaY=0)
img_smoothing_gray_invert = cv2.GaussianBlur(img_invert, (21, 21), sigmaX=0, sigmaY=0)
cv2_imshow(img_smoothing)
cv2_imshow(img_smoothing_gray)
cv2_imshow(img_smoothing_gray_invert)
# Out:
# <PIL.Image.Image image mode=RGB size=202x249 at 0x7F6C6474D950>
# <PIL.Image.Image image mode=L size=202x249 at 0x7F6C64747B90>
# <PIL.Image.Image image mode=L size=202x249 at 0x7F6C64747A50>

# %%
inverted_blurred = 255 - img_smoothing_gray_invert
pencil_sketch = cv2.divide(img_gray, inverted_blurred, scale=256.0)
cv2_imshow(img)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=RGB size=202x249 at 0x7F6C64740410>
# <PIL.Image.Image image mode=L size=202x249 at 0x7F6C64740450>
